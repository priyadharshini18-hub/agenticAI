# %% [markdown]
# ### And welcome to Week 4, Day 3 - more LangGraph..

# %%
from typing import Annotated
from langgraph.graph import StateGraph, START
from langgraph.graph.message import add_messages
from dotenv import load_dotenv
from IPython.display import Image, display
import gradio as gr
from langgraph.prebuilt import ToolNode, tools_condition
import requests
import os
from langchain_openai import ChatOpenAI
from typing import TypedDict

# %%
# Our favorite first step! Crew was doing this for us, by the way.
load_dotenv(override=True)
# Out:
# True

# %% [markdown]
# ### First, let's go set up LangSmith!
#
# https://langsmith.com

# %% [markdown]
# ### Next, here is a useful function in LangChain community:

# %%
from langchain_community.utilities import GoogleSerperAPIWrapper

serper = GoogleSerperAPIWrapper()
serper.run("What is the capital of France?")
# Out:
# 'Paris is the capital and largest city of France, with an estimated population of 2,048,472 in January 2025 in an area of more than 105 km2 (41 sq mi). Paris is the capital and most populous city of France. Situated on the Seine River, in the north of the country, it is in the centre of the Île-de-France ... Paris is the capital of France, the largest country of Europe with 550 000 km2 (65 millions inhabitants). Paris has 2.234 million inhabitants end 2011. The capital of France has been Paris since its liberation in 1944. Paris, city and capital of France, located along the Seine River, in the north-central part of the country. Paris is one of the world\'s most ... Paris is the city of romance par excellence, the fashion capital and the best example of French art de vivre. Exploring Paris is an essential rite of passage ... Paris, the capital of France, is often referred to as the "City of Light" and is renowned for its art, culture, and history. It is home to ... Paris Capital City Of France In 4K Ultra HD Video | Paris, France Capital And Largest City | Paris Is A Major European City And A Global ... Paris became capital of France because France evolved from a federation of counties to a kingdom, where the king was living a Paris. The ... Paris is the capital and most populous city of France go and visit all these landmarks if you get the chance.'

# %% [markdown]
# ### Now here is a LangChain wrapper class for converting functions into Tools

# %%
from langchain.agents import Tool

tool_search =Tool(
        name="search",
        func=serper.run,
        description="Useful for when you need more information from an online search. You MUST use this tool for answering any factual or knowledge-based queries such as currency conversion, capitals, current events, or facts."
    )

# %% [markdown]
# ### Now we can try out the tool the langchain way

# %%
tool_search.invoke("what is the rupee conversion of $1?")
# Out:
# "Convert 1 USD to INR with the Wise Currency Converter. Analyze historical currency charts or live US dollar / Indian rupee rates and get free rate alerts ... Check today's USD to INR exchange rate with Western Union's currency converter. Send USD and your receiver will get INR in minutes. Today i.e.Sunday 14/09/2025 , for 1 US Dollar you get 88.31 Indian Rupees. Change in USD to INR rate from previous day is -0.08%. Moreover, we have also added ... Convert US Dollar to Indian Rupee ; 1 USD, 88.3281 INR ; 5 USD, 441.641 INR ; 10 USD, 883.281 INR ; 25 USD, 2,208.2 INR. Join today and get a promotional rate of 88.67 INR to 1 USD on your first money transfer. Special rate. 1 USD = 88.67 INR. USD to INR exchange rates today ; 1 USD, 88.28 INR ; 5 USD, 441.39 INR ; 10 USD, 882.77 INR ; 20 USD, 1,765.54 INR. Currently, 1 USD stands at approximately INR 88.4996. How Can I Convert US Dollar to INR in India. Some common ways to exchange US Dollar currency with INR in ... 1 USD To INR Convert United States Dollar To Indian Rupee · 1 USD = 88.27785 INR Sep 14, 2025 15:56 UTC · 88.27785 Indian Rupee. 1.00₹. From. INR - Indian Rupee. To. USD - US Dollar. 1.00 Indian Rupee = 0.011323939 US Dollar. 1 USD = 88.3085 INR. Indian Rupee to US Dollar conversion — ... $1 = ₹87.8501. Additional fees. $0.01. Get startedExchange rates ... Before converting US Dollars to Indian Rupees, use our currency converter, conversion ..."

# %% [markdown]
# ### And now let's write a tool ourselves
#
# We'll pick a familiar one

# %%
pushover_token = os.getenv("PUSHOVER_TOKEN")
pushover_user = os.getenv("PUSHOVER_USER")
pushover_url = "https://api.pushover.net/1/messages.json"

def push(text: str):
    """Send a push notification to the user"""
    requests.post(pushover_url, data = {"token": pushover_token, "user": pushover_user, "message": text})

# %%
tool_push = Tool(
        name="send_push_notification",
        func=push,
        description="useful for when you want to send a push notification"
    )

tool_push.invoke("Hello, me")

# %% [markdown]
# ### Back to the Graph from yesterday
#
# One small change - using TypedDict instead of BaseModel for the State object
#
# When we implement tools, we always need to make 2 changes to the code:
#
# 1. Changes to provide the tools to OpenAI in json when we make the call
#
# 2. Changes to handle the results back: look for the model staying that the finish_reason=="tool_calls" and then retrieve the call, run the function, provide the results.

# %% [markdown]
# ### Bring them together

# %%
tools = [tool_search, tool_push]

# %%
# Step 1: Define the State object
class State(TypedDict):
    messages: Annotated[list, add_messages]

# %%
# Step 2: Start the Graph Builder with this State class
graph_builder = StateGraph(State)

# %%
# This is different:

# llm = ChatOpenAI(model="gpt-4o-mini")
# llm_with_tools = llm.bind_tools(tools)

from langchain_google_genai import ChatGoogleGenerativeAI

llm = ChatGoogleGenerativeAI(
    model="gemini-1.5-flash",     # or gemini-1.5-pro
    api_key=os.getenv("GEMINI_API_KEY")
)
llm_with_tools = llm.bind_tools(tools)

# %%
# Step 3: Create a Node


def chatbot(state: State):
    return {"messages": [llm_with_tools.invoke(state["messages"])]}

graph_builder.add_node("chatbot", chatbot)
graph_builder.add_node("tools", ToolNode(tools=tools))

# %%
# Step 4: Create Edges


graph_builder.add_conditional_edges( "chatbot", tools_condition, "tools")

# Any time a tool is called, we return to the chatbot to decide the next step
graph_builder.add_edge("tools", "chatbot")
graph_builder.add_edge(START, "chatbot")

# %%
# Step 5: Compile the Graph
graph = graph_builder.compile()
display(Image(graph.get_graph().draw_mermaid_png()))

# %% [markdown]
# ### That's it! And, let's do this:

# %%
def chat(user_input: str, history):
    result = graph.invoke({"messages": [{"role": "user", "content": user_input}]})
    return result["messages"][-1].content


gr.ChatInterface(chat, type="messages").launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7862
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7862/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %% [markdown]
# ## OK it's time to add Memory!
#
# ### BUT WAIT!
#
# We have this whole Graph maintaining the state and appending to the state.
#
# Why isn't this handling memory?
#
# ### This is a crucial point for understanding LangGraph
#
# > A super-step can be considered a single iteration over the graph nodes. Nodes that run in parallel are part of the same super-step, while nodes that run sequentially belong to separate super-steps.
#
#
# One "Super-Step" of the graph represents one invocation of passing messages between agents.
#
# In idomatic LangGraph, you call invoke to run your graph for each super-step; for each interaction.
#
# The reducer handles state updates automatically within one super-step, but not between them.
#
# That is what checkpointing achieves.

# %%
from langgraph.checkpoint.memory import MemorySaver

memory = MemorySaver()

# %%
# Steps 1 and 2
graph_builder = StateGraph(State)


# Step 3
llm = ChatGoogleGenerativeAI(
    model="gemini-1.5-flash",   
    api_key=os.getenv("GEMINI_API_KEY")
)
llm_with_tools = llm.bind_tools(tools)

def chatbot(state: State):
    print(state)
    return {"messages": [llm_with_tools.invoke(state["messages"])]}

graph_builder.add_node("chatbot", chatbot)
graph_builder.add_node("tools", ToolNode(tools=tools))

# Step 4
graph_builder.add_conditional_edges( "chatbot", tools_condition, "tools")
graph_builder.add_edge("tools", "chatbot")
graph_builder.add_edge(START, "chatbot")

# Step 5
graph = graph_builder.compile(checkpointer=memory)
display(Image(graph.get_graph().draw_mermaid_png()))

# %%
config = {"configurable": {"thread_id": "1"}}

def chat(user_input: str, history):
    result = graph.invoke({"messages": [{"role": "user", "content": user_input}]}, config=config)
    return result["messages"][-1].content


gr.ChatInterface(chat, type="messages").launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7863
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7863/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# {'messages': [HumanMessage(content='hi', additional_kwargs={}, response_metadata={}, id='33234813-63d0-4c23-b948-aa5e58e2c942')]}
# {'messages': [HumanMessage(content='hi', additional_kwargs={}, response_metadata={}, id='33234813-63d0-4c23-b948-aa5e58e2c942'), AIMessage(content='Hello! How can I help you today?', additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'safety_ratings': []}, id='run--ebcd353c-50ec-480f-b20e-6e1359b53cbd-0', usage_metadata={'input_tokens': 72, 'output_tokens': 10, 'total_tokens': 82, 'input_token_details': {'cache_read': 0}}), HumanMessage(content='my name is priya', additional_kwargs={}, response_metadata={}, id='6bf90083-47a5-4212-ac91-d1c03f528de5')]}
# {'messages': [HumanMessage(content='hi', additional_kwargs={}, response_metadata={}, id='33234813-63d0-4c23-b948-aa5e58e2c942'), AIMessage(content='Hello! How can I help you today?', additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'safety_ratings': []}, id='run--ebcd353c-50ec-480f-b20e-6e1359b53cbd-0', usage_metadata={'input_tokens': 72, 'output_tokens': 10, 'total_tokens': 82, 'input_token_details': {'cache_read': 0}}), HumanMessage(content='my name is priya', additional_kwargs={}, response_metadata={}, id='6bf90083-47a5-4212-ac91-d1c03f528de5'), AIMessage(content='Nice to meet you, Priya!  Is there anything I can assist you with?', additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'safety_ratings': []}, id='run--53c0e928-a543-47e6-9fce-dec1eac9e317-0', usage_metadata={'input_tokens': 86, 'output_tokens': 18, 'total_tokens': 104, 'input_token_details': {'cache_read': 0}}), HumanMessage(content="what is india's capital?", additional_kwargs={}, response_metadata={}, id='99c83094-3f9f-41ba-93dd-614cbe622c2d')]}
# {'messages': [HumanMessage(content='hi', additional_kwargs={}, response_metadata={}, id='33234813-63d0-4c23-b948-aa5e58e2c942'), AIMessage(content='Hello! How can I help you today?', additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'safety_ratings': []}, id='run--ebcd353c-50ec-480f-b20e-6e1359b53cbd-0', usage_metadata={'input_tokens': 72, 'output_tokens': 10, 'total_tokens': 82, 'input_token_details': {'cache_read': 0}}), HumanMessage(content='my name is priya', additional_kwargs={}, response_metadata={}, id='6bf90083-47a5-4212-ac91-d1c03f528de5'), AIMessage(content='Nice to meet you, Priya!  Is there anything I can assist you with?', additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'safety_ratings': []}, id='run--53c0e928-a543-47e6-9fce-dec1eac9e317-0', usage_metadata={'input_tokens': 86, 'output_tokens': 18, 'total_tokens': 104, 'input_token_details': {'cache_read': 0}}), HumanMessage(content="what is india's capital?", additional_kwargs={}, response_metadata={}, id='99c83094-3f9f-41ba-93dd-614cbe622c2d'), AIMessage(content='', additional_kwargs={'function_call': {'name': 'search', 'arguments': '{"__arg1": "India capital"}'}}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'safety_ratings': []}, id='run--aac4493f-56e5-4b46-9c3d-75eb56d5a815-0', tool_calls=[{'name': 'search', 'args': {'__arg1': 'India capital'}, 'id': '8597d68e-eee3-4954-900b-471354a56953', 'type': 'tool_call'}], usage_metadata={'input_tokens': 110, 'output_tokens': 6, 'total_tokens': 116, 'input_token_details': {'cache_read': 0}}), ToolMessage(content="New Delhi is the capital of India and a part of the National Capital Territory of Delhi (NCT). New Delhi is the seat of all three branches of the Government ... Delhi, officially the National Capital Territory (NCT) of Delhi, is a city and a union territory of India containing New Delhi, the capital of India. New Delhi, national capital of India. It is situated in the north-central part of the country on the west bank of the Yamuna River. India Capital has invested exclusively in Indian public equities since 1994. We focus intensively on fundamental research to identify long-term investments ... Thus, in 1911, New Delhi became the capital of India, south of the Old City of Delhi. And then over the years, Delhi expanded, and satellite ... From its origins as 'Indraprastha' in the Mahabharata to becoming the capital in 1911, Delhi blends ancient charm and modern governance. Its appealing old monuments, busy street bazaars and chaotic traffic roads make Delhi one of the most intense destinations that you can visit. There are 28 states and 8 Union territories in the country. Union Territories are administered by the President through an Administrator appointed by him/her. What is the Capital of India? Capital City, New Delhi. Capital location, 28 36 N, 77 12 E. Capital - history, the city's name is associated with various myths ... Lying in the northern part of the country, Delhi is surrounded by Haryana on all sides except the east, where it borders with Uttar Pradesh.", name='search', id='0e690daf-bf1f-4101-a187-86446ffb36be', tool_call_id='8597d68e-eee3-4954-900b-471354a56953')]}
# {'messages': [HumanMessage(content='hi', additional_kwargs={}, response_metadata={}, id='33234813-63d0-4c23-b948-aa5e58e2c942'), AIMessage(content='Hello! How can I help you today?', additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'safety_ratings': []}, id='run--ebcd353c-50ec-480f-b20e-6e1359b53cbd-0', usage_metadata={'input_tokens': 72, 'output_tokens': 10, 'total_tokens': 82, 'input_token_details': {'cache_read': 0}}), HumanMessage(content='my name is priya', additional_kwargs={}, response_metadata={}, id='6bf90083-47a5-4212-ac91-d1c03f528de5'), AIMessage(content='Nice to meet you, Priya!  Is there anything I can assist you with?', additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'safety_ratings': []}, id='run--53c0e928-a543-47e6-9fce-dec1eac9e317-0', usage_metadata={'input_tokens': 86, 'output_tokens': 18, 'total_tokens': 104, 'input_token_details': {'cache_read': 0}}), HumanMessage(content="what is india's capital?", additional_kwargs={}, response_metadata={}, id='99c83094-3f9f-41ba-93dd-614cbe622c2d'), AIMessage(content='', additional_kwargs={'function_call': {'name': 'search', 'arguments': '{"__arg1": "India capital"}'}}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'safety_ratings': []}, id='run--aac4493f-56e5-4b46-9c3d-75eb56d5a815-0', tool_calls=[{'name': 'search', 'args': {'__arg1': 'India capital'}, 'id': '8597d68e-eee3-4954-900b-471354a56953', 'type': 'tool_call'}], usage_metadata={'input_tokens': 110, 'output_tokens': 6, 'total_tokens': 116, 'input_token_details': {'cache_read': 0}}), ToolMessage(content="New Delhi is the capital of India and a part of the National Capital Territory of Delhi (NCT). New Delhi is the seat of all three branches of the Government ... Delhi, officially the National Capital Territory (NCT) of Delhi, is a city and a union territory of India containing New Delhi, the capital of India. New Delhi, national capital of India. It is situated in the north-central part of the country on the west bank of the Yamuna River. India Capital has invested exclusively in Indian public equities since 1994. We focus intensively on fundamental research to identify long-term investments ... Thus, in 1911, New Delhi became the capital of India, south of the Old City of Delhi. And then over the years, Delhi expanded, and satellite ... From its origins as 'Indraprastha' in the Mahabharata to becoming the capital in 1911, Delhi blends ancient charm and modern governance. Its appealing old monuments, busy street bazaars and chaotic traffic roads make Delhi one of the most intense destinations that you can visit. There are 28 states and 8 Union territories in the country. Union Territories are administered by the President through an Administrator appointed by him/her. What is the Capital of India? Capital City, New Delhi. Capital location, 28 36 N, 77 12 E. Capital - history, the city's name is associated with various myths ... Lying in the northern part of the country, Delhi is surrounded by Haryana on all sides except the east, where it borders with Uttar Pradesh.", name='search', id='0e690daf-bf1f-4101-a187-86446ffb36be', tool_call_id='8597d68e-eee3-4954-900b-471354a56953'), AIMessage(content='The capital of India is New Delhi.', additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'safety_ratings': []}, id='run--d820dbad-c450-4a07-9eda-372b6547d871-0', usage_metadata={'input_tokens': 443, 'output_tokens': 9, 'total_tokens': 452, 'input_token_details': {'cache_read': 0}}), HumanMessage(content='what is 2+2?', additional_kwargs={}, response_metadata={}, id='59b99c6b-93ba-4cf4-b54f-26c357080471')]}
# {'messages': [HumanMessage(content='hi', additional_kwargs={}, response_metadata={}, id='33234813-63d0-4c23-b948-aa5e58e2c942'), AIMessage(content='Hello! How can I help you today?', additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'safety_ratings': []}, id='run--ebcd353c-50ec-480f-b20e-6e1359b53cbd-0', usage_metadata={'input_tokens': 72, 'output_tokens': 10, 'total_tokens': 82, 'input_token_details': {'cache_read': 0}}), HumanMessage(content='my name is priya', additional_kwargs={}, response_metadata={}, id='6bf90083-47a5-4212-ac91-d1c03f528de5'), AIMessage(content='Nice to meet you, Priya!  Is there anything I can assist you with?', additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'safety_ratings': []}, id='run--53c0e928-a543-47e6-9fce-dec1eac9e317-0', usage_metadata={'input_tokens': 86, 'output_tokens': 18, 'total_tokens': 104, 'input_token_details': {'cache_read': 0}}), HumanMessage(content="what is india's capital?", additional_kwargs={}, response_metadata={}, id='99c83094-3f9f-41ba-93dd-614cbe622c2d'), AIMessage(content='', additional_kwargs={'function_call': {'name': 'search', 'arguments': '{"__arg1": "India capital"}'}}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'safety_ratings': []}, id='run--aac4493f-56e5-4b46-9c3d-75eb56d5a815-0', tool_calls=[{'name': 'search', 'args': {'__arg1': 'India capital'}, 'id': '8597d68e-eee3-4954-900b-471354a56953', 'type': 'tool_call'}], usage_metadata={'input_tokens': 110, 'output_tokens': 6, 'total_tokens': 116, 'input_token_details': {'cache_read': 0}}), ToolMessage(content="New Delhi is the capital of India and a part of the National Capital Territory of Delhi (NCT). New Delhi is the seat of all three branches of the Government ... Delhi, officially the National Capital Territory (NCT) of Delhi, is a city and a union territory of India containing New Delhi, the capital of India. New Delhi, national capital of India. It is situated in the north-central part of the country on the west bank of the Yamuna River. India Capital has invested exclusively in Indian public equities since 1994. We focus intensively on fundamental research to identify long-term investments ... Thus, in 1911, New Delhi became the capital of India, south of the Old City of Delhi. And then over the years, Delhi expanded, and satellite ... From its origins as 'Indraprastha' in the Mahabharata to becoming the capital in 1911, Delhi blends ancient charm and modern governance. Its appealing old monuments, busy street bazaars and chaotic traffic roads make Delhi one of the most intense destinations that you can visit. There are 28 states and 8 Union territories in the country. Union Territories are administered by the President through an Administrator appointed by him/her. What is the Capital of India? Capital City, New Delhi. Capital location, 28 36 N, 77 12 E. Capital - history, the city's name is associated with various myths ... Lying in the northern part of the country, Delhi is surrounded by Haryana on all sides except the east, where it borders with Uttar Pradesh.", name='search', id='0e690daf-bf1f-4101-a187-86446ffb36be', tool_call_id='8597d68e-eee3-4954-900b-471354a56953'), AIMessage(content='The capital of India is New Delhi.', additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'safety_ratings': []}, id='run--d820dbad-c450-4a07-9eda-372b6547d871-0', usage_metadata={'input_tokens': 443, 'output_tokens': 9, 'total_tokens': 452, 'input_token_details': {'cache_read': 0}}), HumanMessage(content='what is 2+2?', additional_kwargs={}, response_metadata={}, id='59b99c6b-93ba-4cf4-b54f-26c357080471'), AIMessage(content='2 + 2 = 4', additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings' ...

# %%
graph.get_state(config)
# Out:
# StateSnapshot(values={'messages': [HumanMessage(content='hi', additional_kwargs={}, response_metadata={}, id='33234813-63d0-4c23-b948-aa5e58e2c942'), AIMessage(content='Hello! How can I help you today?', additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'safety_ratings': []}, id='run--ebcd353c-50ec-480f-b20e-6e1359b53cbd-0', usage_metadata={'input_tokens': 72, 'output_tokens': 10, 'total_tokens': 82, 'input_token_details': {'cache_read': 0}}), HumanMessage(content='my name is priya', additional_kwargs={}, response_metadata={}, id='6bf90083-47a5-4212-ac91-d1c03f528de5'), AIMessage(content='Nice to meet you, Priya!  Is there anything I can assist you with?', additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'safety_ratings': []}, id='run--53c0e928-a543-47e6-9fce-dec1eac9e317-0', usage_metadata={'input_tokens': 86, 'output_tokens': 18, 'total_tokens': 104, 'input_token_details': {'cache_read': 0}}), HumanMessage(content="what is india's capital?", additional_kwargs={}, response_metadata={}, id='99c83094-3f9f-41ba-93dd-614cbe622c2d'), AIMessage(content='', additional_kwargs={'function_call': {'name': 'search', 'arguments': '{"__arg1": "India capital"}'}}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'safety_ratings': []}, id='run--aac4493f-56e5-4b46-9c3d-75eb56d5a815-0', tool_calls=[{'name': 'search', 'args': {'__arg1': 'India capital'}, 'id': '8597d68e-eee3-4954-900b-471354a56953', 'type': 'tool_call'}], usage_metadata={'input_tokens': 110, 'output_tokens': 6, 'total_tokens': 116, 'input_token_details': {'cache_read': 0}}), ToolMessage(content="New Delhi is the capital of India and a part of the National Capital Territory of Delhi (NCT). New Delhi is the seat of all three branches of the Government ... Delhi, officially the National Capital Territory (NCT) of Delhi, is a city and a union territory of India containing New Delhi, the capital of India. New Delhi, national capital of India. It is situated in the north-central part of the country on the west bank of the Yamuna River. India Capital has invested exclusively in Indian public equities since 1994. We focus intensively on fundamental research to identify long-term investments ... Thus, in 1911, New Delhi became the capital of India, south of the Old City of Delhi. And then over the years, Delhi expanded, and satellite ... From its origins as 'Indraprastha' in the Mahabharata to becoming the capital in 1911, Delhi blends ancient charm and modern governance. Its appealing old monuments, busy street bazaars and chaotic traffic roads make Delhi one of the most intense destinations that you can visit. There are 28 states and 8 Union territories in the country. Union Territories are administered by the President through an Administrator appointed by him/her. What is the Capital of India? Capital City, New Delhi. Capital location, 28 36 N, 77 12 E. Capital - history, the city's name is associated with various myths ... Lying in the northern part of the country, Delhi is surrounded by Haryana on all sides except the east, where it borders with Uttar Pradesh.", name='search', id='0e690daf-bf1f-4101-a187-86446ffb36be', tool_call_id='8597d68e-eee3-4954-900b-471354a56953'), AIMessage(content='The capital of India is New Delhi.', additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'safety_ratings': []}, id='run--d820dbad-c450-4a07-9eda-372b6547d871-0', usage_metadata={'input_tokens': 443, 'output_tokens': 9, 'total_tokens': 452, 'input_token_details': {'cache_read': 0}}), HumanMessage(content='what is 2+2?', additional_kwargs={}, response_metadata={}, id='59b99c6b-93ba-4cf4-b54f-26c357080471'), AIMessage(content='2 + 2 = 4', additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason' ...

# %%
# Most recent first

list(graph.get_state_history(config))
# Out:
# [StateSnapshot(values={'messages': [HumanMessage(content='hi', additional_kwargs={}, response_metadata={}, id='33234813-63d0-4c23-b948-aa5e58e2c942'), AIMessage(content='Hello! How can I help you today?', additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'safety_ratings': []}, id='run--ebcd353c-50ec-480f-b20e-6e1359b53cbd-0', usage_metadata={'input_tokens': 72, 'output_tokens': 10, 'total_tokens': 82, 'input_token_details': {'cache_read': 0}}), HumanMessage(content='my name is priya', additional_kwargs={}, response_metadata={}, id='6bf90083-47a5-4212-ac91-d1c03f528de5'), AIMessage(content='Nice to meet you, Priya!  Is there anything I can assist you with?', additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'safety_ratings': []}, id='run--53c0e928-a543-47e6-9fce-dec1eac9e317-0', usage_metadata={'input_tokens': 86, 'output_tokens': 18, 'total_tokens': 104, 'input_token_details': {'cache_read': 0}}), HumanMessage(content="what is india's capital?", additional_kwargs={}, response_metadata={}, id='99c83094-3f9f-41ba-93dd-614cbe622c2d'), AIMessage(content='', additional_kwargs={'function_call': {'name': 'search', 'arguments': '{"__arg1": "India capital"}'}}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'safety_ratings': []}, id='run--aac4493f-56e5-4b46-9c3d-75eb56d5a815-0', tool_calls=[{'name': 'search', 'args': {'__arg1': 'India capital'}, 'id': '8597d68e-eee3-4954-900b-471354a56953', 'type': 'tool_call'}], usage_metadata={'input_tokens': 110, 'output_tokens': 6, 'total_tokens': 116, 'input_token_details': {'cache_read': 0}}), ToolMessage(content="New Delhi is the capital of India and a part of the National Capital Territory of Delhi (NCT). New Delhi is the seat of all three branches of the Government ... Delhi, officially the National Capital Territory (NCT) of Delhi, is a city and a union territory of India containing New Delhi, the capital of India. New Delhi, national capital of India. It is situated in the north-central part of the country on the west bank of the Yamuna River. India Capital has invested exclusively in Indian public equities since 1994. We focus intensively on fundamental research to identify long-term investments ... Thus, in 1911, New Delhi became the capital of India, south of the Old City of Delhi. And then over the years, Delhi expanded, and satellite ... From its origins as 'Indraprastha' in the Mahabharata to becoming the capital in 1911, Delhi blends ancient charm and modern governance. Its appealing old monuments, busy street bazaars and chaotic traffic roads make Delhi one of the most intense destinations that you can visit. There are 28 states and 8 Union territories in the country. Union Territories are administered by the President through an Administrator appointed by him/her. What is the Capital of India? Capital City, New Delhi. Capital location, 28 36 N, 77 12 E. Capital - history, the city's name is associated with various myths ... Lying in the northern part of the country, Delhi is surrounded by Haryana on all sides except the east, where it borders with Uttar Pradesh.", name='search', id='0e690daf-bf1f-4101-a187-86446ffb36be', tool_call_id='8597d68e-eee3-4954-900b-471354a56953'), AIMessage(content='The capital of India is New Delhi.', additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'safety_ratings': []}, id='run--d820dbad-c450-4a07-9eda-372b6547d871-0', usage_metadata={'input_tokens': 443, 'output_tokens': 9, 'total_tokens': 452, 'input_token_details': {'cache_read': 0}}), HumanMessage(content='what is 2+2?', additional_kwargs={}, response_metadata={}, id='59b99c6b-93ba-4cf4-b54f-26c357080471'), AIMessage(content='2 + 2 = 4', additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason ...
#  StateSnapshot(values={'messages': [HumanMessage(content='hi', additional_kwargs={}, response_metadata={}, id='33234813-63d0-4c23-b948-aa5e58e2c942'), AIMessage(content='Hello! How can I help you today?', additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'safety_ratings': []}, id='run--ebcd353c-50ec-480f-b20e-6e1359b53cbd-0', usage_metadata={'input_tokens': 72, 'output_tokens': 10, 'total_tokens': 82, 'input_token_details': {'cache_read': 0}}), HumanMessage(content='my name is priya', additional_kwargs={}, response_metadata={}, id='6bf90083-47a5-4212-ac91-d1c03f528de5'), AIMessage(content='Nice to meet you, Priya!  Is there anything I can assist you with?', additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'safety_ratings': []}, id='run--53c0e928-a543-47e6-9fce-dec1eac9e317-0', usage_metadata={'input_tokens': 86, 'output_tokens': 18, 'total_tokens': 104, 'input_token_details': {'cache_read': 0}}), HumanMessage(content="what is india's capital?", additional_kwargs={}, response_metadata={}, id='99c83094-3f9f-41ba-93dd-614cbe622c2d'), AIMessage(content='', additional_kwargs={'function_call': {'name': 'search', 'arguments': '{"__arg1": "India capital"}'}}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'safety_ratings': []}, id='run--aac4493f-56e5-4b46-9c3d-75eb56d5a815-0', tool_calls=[{'name': 'search', 'args': {'__arg1': 'India capital'}, 'id': '8597d68e-eee3-4954-900b-471354a56953', 'type': 'tool_call'}], usage_metadata={'input_tokens': 110, 'output_tokens': 6, 'total_tokens': 116, 'input_token_details': {'cache_read': 0}}), ToolMessage(content="New Delhi is the capital of India and a part of the National Capital Territory of Delhi (NCT). New Delhi is the seat of all three branches of the Government ... Delhi, officially the National Capital Territory (NCT) of Delhi, is a city and a union territory of India containing New Delhi, the capital of India. New Delhi, national capital of India. It is situated in the north-central part of the country on the west bank of the Yamuna River. India Capital has invested exclusively in Indian public equities since 1994. We focus intensively on fundamental research to identify long-term investments ... Thus, in 1911, New Delhi became the capital of India, south of the Old City of Delhi. And then over the years, Delhi expanded, and satellite ... From its origins as 'Indraprastha' in the Mahabharata to becoming the capital in 1911, Delhi blends ancient charm and modern governance. Its appealing old monuments, busy street bazaars and chaotic traffic roads make Delhi one of the most intense destinations that you can visit. There are 28 states and 8 Union territories in the country. Union Territories are administered by the President through an Administrator appointed by him/her. What is the Capital of India? Capital City, New Delhi. Capital location, 28 36 N, 77 12 E. Capital - history, the city's name is associated with various myths ... Lying in the northern part of the country, Delhi is surrounded by Haryana on all sides except the east, where it borders with Uttar Pradesh.", name='search', id='0e690daf-bf1f-4101-a187-86446ffb36be', tool_call_id='8597d68e-eee3-4954-900b-471354a56953'), AIMessage(content='The capital of India is New Delhi.', additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'safety_ratings': []}, id='run--d820dbad-c450-4a07-9eda-372b6547d871-0', usage_metadata={'input_tokens': 443, 'output_tokens': 9, 'total_tokens': 452, 'input_token_details': {'cache_read': 0}}), HumanMessage(content='what is 2+2?', additional_kwargs={}, response_metadata={}, id='59b99c6b-93ba-4cf4-b54f-26c357080471'), AIMessage(content='2 + 2 = 4', additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason ...
#  StateSnapshot(values={'messages': [HumanMessage(content='hi', additional_kwargs={}, response_metadata={}, id='33234813-63d0-4c23-b948-aa5e58e2c942'), AIMessage(content='Hello! How can I help you today?', additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'safety_ratings': []}, id='run--ebcd353c-50ec-480f-b20e-6e1359b53cbd-0', usage_metadata={'input_tokens': 72, 'output_tokens': 10, 'total_tokens': 82, 'input_token_details': {'cache_read': 0}}), HumanMessage(content='my name is priya', additional_kwargs={}, response_metadata={}, id='6bf90083-47a5-4212-ac91-d1c03f528de5'), AIMessage(content='Nice to meet you, Priya!  Is there anything I can assist you with?', additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'safety_ratings': []}, id='run--53c0e928-a543-47e6-9fce-dec1eac9e317-0', usage_metadata={'input_tokens': 86, 'output_tokens': 18, 'total_tokens': 104, 'input_token_details': {'cache_read': 0}}), HumanMessage(content="what is india's capital?", additional_kwargs={}, response_metadata={}, id='99c83094-3f9f-41ba-93dd-614cbe622c2d'), AIMessage(content='', additional_kwargs={'function_call': {'name': 'search', 'arguments': '{"__arg1": "India capital"}'}}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'safety_ratings': []}, id='run--aac4493f-56e5-4b46-9c3d-75eb56d5a815-0', tool_calls=[{'name': 'search', 'args': {'__arg1': 'India capital'}, 'id': '8597d68e-eee3-4954-900b-471354a56953', 'type': 'tool_call'}], usage_metadata={'input_tokens': 110, 'output_tokens': 6, 'total_tokens': 116, 'input_token_details': {'cache_read': 0}}), ToolMessage(content="New Delhi is the capital of India and a part of the National Capital Territory of Delhi (NCT). New Delhi is the seat of all three branches of the Government ... Delhi, officially the National Capital Territory (NCT) of Delhi, is a city and a union territory of India containing New Delhi, the capital of India. New Delhi, national capital of India. It is situated in the north-central part of the country on the west bank of the Yamuna River. India Capital has invested exclusively in Indian public equities since 1994. We focus intensively on fundamental research to identify long-term investments ... Thus, in 1911, New Delhi became the capital of India, south of the Old City of Delhi. And then over the years, Delhi expanded, and satellite ... From its origins as 'Indraprastha' in the Mahabharata to becoming the capital in 1911, Delhi blends ancient charm and modern governance. Its appealing old monuments, busy street bazaars and chaotic traffic roads make Delhi one of the most intense destinations that you can visit. There are 28 states and 8 Union territories in the country. Union Territories are administered by the President through an Administrator appointed by him/her. What is the Capital of India? Capital City, New Delhi. Capital location, 28 36 N, 77 12 E. Capital - history, the city's name is associated with various myths ... Lying in the northern part of the country, Delhi is surrounded by Haryana on all sides except the east, where it borders with Uttar Pradesh.", name='search', id='0e690daf-bf1f-4101-a187-86446ffb36be', tool_call_id='8597d68e-eee3-4954-900b-471354a56953'), AIMessage(content='The capital of India is New Delhi.', additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'safety_ratings': []}, id='run--d820dbad-c450-4a07-9eda-372b6547d871-0', usage_metadata={'input_tokens': 443, 'output_tokens': 9, 'total_tokens': 452, 'input_token_details': {'cache_read': 0}}), HumanMessage(content='what is 2+2?', additional_kwargs={}, response_metadata={}, id='59b99c6b-93ba-4cf4-b54f-26c357080471'), AIMessage(content='2 + 2 = 4', additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason ...
#  StateSnapshot(values={'messages': [HumanMessage(content='hi', additional_kwargs={}, response_metadata={}, id='33234813-63d0-4c23-b948-aa5e58e2c942'), AIMessage(content='Hello! How can I help you today?', additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'safety_ratings': []}, id='run--ebcd353c-50ec-480f-b20e-6e1359b53cbd-0', usage_metadata={'input_tokens': 72, 'output_tokens': 10, 'total_tokens': 82, 'input_token_details': {'cache_read': 0}}), HumanMessage(content='my name is priya', additional_kwargs={}, response_metadata={}, id='6bf90083-47a5-4212-ac91-d1c03f528de5'), AIMessage(content='Nice to meet you, Priya!  Is there anything I can assist you with?', additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'safety_ratings': []}, id='run--53c0e928-a543-47e6-9fce-dec1eac9e317-0', usage_metadata={'input_tokens': 86, 'output_tokens': 18, 'total_tokens': 104, 'input_token_details': {'cache_read': 0}}), HumanMessage(content="what is india's capital?", additional_kwargs={}, response_metadata={}, id='99c83094-3f9f-41ba-93dd-614cbe622c2d'), AIMessage(content='', additional_kwargs={'function_call': {'name': 'search', 'arguments': '{"__arg1": "India capital"}'}}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'safety_ratings': []}, id='run--aac4493f-56e5-4b46-9c3d-75eb56d5a815-0', tool_calls=[{'name': 'search', 'args': {'__arg1': 'India capital'}, 'id': '8597d68e-eee3-4954-900b-471354a56953', 'type': 'tool_call'}], usage_metadata={'input_tokens': 110, 'output_tokens': 6, 'total_tokens': 116, 'input_token_details': {'cache_read': 0}}), ToolMessage(content="New Delhi is the capital of India and a part of the National Capital Territory of Delhi (NCT). New Delhi is the seat of all three branches of the Government ... Delhi, officially the National Capital Territory (NCT) of Delhi, is a city and a union territory of India containing New Delhi, the capital of India. New Delhi, national capital of India. It is situated in the north-central part of the country on the west bank of the Yamuna River. India Capital has invested exclusively in Indian public equities since 1994. We focus intensively on fundamental research to identify long-term investments ... Thus, in 1911, New Delhi became the capital of India, south of the Old City of Delhi. And then over the years, Delhi expanded, and satellite ... From its origins as 'Indraprastha' in the Mahabharata to becoming the capital in 1911, Delhi blends ancient charm and modern governance. Its appealing old monuments, busy street bazaars and chaotic traffic roads make Delhi one of the most intense destinations that you can visit. There are 28 states and 8 Union territories in the country. Union Territories are administered by the President through an Administrator appointed by him/her. What is the Capital of India? Capital City, New Delhi. Capital location, 28 36 N, 77 12 E. Capital - history, the city's name is associated with various myths ... Lying in the northern part of the country, Delhi is surrounded by Haryana on all sides except the east, where it borders with Uttar Pradesh.", name='search', id='0e690daf-bf1f-4101-a187-86446ffb36be', tool_call_id='8597d68e-eee3-4954-900b-471354a56953'), AIMessage(content='The capital of India is New Delhi.', additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'safety_ratings': []}, id='run--d820dbad-c450-4a07-9eda-372b6547d871-0', usage_metadata={'input_tokens': 443, 'output_tokens': 9, 'total_tokens': 452, 'input_token_details': {'cache_read': 0}}), HumanMessage(content='what is 2+2?', additional_kwargs={}, response_metadata={}, id='59b99c6b-93ba-4cf4-b54f-26c357080471'), AIMessage(content='2 + 2 = 4', additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason ...
#  StateSnapshot(values={'messages': [HumanMessage(content='hi', additional_kwargs={}, response_metadata={}, id='33234813-63d0-4c23-b948-aa5e58e2c942'), AIMessage(content='Hello! How can I help you today?', additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'safety_ratings': []}, id='run--ebcd353c-50ec-480f-b20e-6e1359b53cbd-0', usage_metadata={'input_tokens': 72, 'output_tokens': 10, 'total_tokens': 82, 'input_token_details': {'cache_read': 0}}), HumanMessage(content='my name is priya', additional_kwargs={}, response_metadata={}, id='6bf90083-47a5-4212-ac91-d1c03f528de5'), AIMessage(content='Nice to meet you, Priya!  Is there anything I can assist you with?', additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'safety_ratings': []}, id='run--53c0e928-a543-47e6-9fce-dec1eac9e317-0', usage_metadata={'input_tokens': 86, 'output_tokens': 18, 'total_tokens': 104, 'input_token_details': {'cache_read': 0}}), HumanMessage(content="what is india's capital?", additional_kwargs={}, response_metadata={}, id='99c83094-3f9f-41ba-93dd-614cbe622c2d'), AIMessage(content='', additional_kwargs={'function_call': {'name': 'search', 'arguments': '{"__arg1": "India capital"}'}}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'safety_ratings': []}, id='run--aac4493f-56e5-4b46-9c3d-75eb56d5a815-0', tool_calls=[{'name': 'search', 'args': {'__arg1': 'India capital'}, 'id': '8597d68e-eee3-4954-900b-471354a56953', 'type': 'tool_call'}], usage_metadata={'input_tokens': 110, 'output_tokens': 6, 'total_tokens': 116, 'input_token_details': {'cache_read': 0}}), ToolMessage(content="New Delhi is the capital of India and a part of the National Capital Territory of Delhi (NCT). New Delhi is the seat of all three branches of the Government ... Delhi, officially the National Capital Territory (NCT) of Delhi, is a city and a union territory of India containing New Delhi, the capital of India. New Delhi, national capital of India. It is situated in the north-central part of the country on the west bank of the Yamuna River. India Capital has invested exclusively in Indian public equities since 1994. We focus intensively on fundamental research to identify long-term investments ... Thus, in 1911, New Delhi became the capital of India, south of the Old City of Delhi. And then over the years, Delhi expanded, and satellite ... From its origins as 'Indraprastha' in the Mahabharata to becoming the capital in 1911, Delhi blends ancient charm and modern governance. Its appealing old monuments, busy street bazaars and chaotic traffic roads make Delhi one of the most intense destinations that you can visit. There are 28 states and 8 Union territories in the country. Union Territories are administered by the President through an Administrator appointed by him/her. What is the Capital of India? Capital City, New Delhi. Capital location, 28 36 N, 77 12 E. Capital - history, the city's name is associated with various myths ... Lying in the northern part of the country, Delhi is surrounded by Haryana on all sides except the east, where it borders with Uttar Pradesh.", name='search', id='0e690daf-bf1f-4101-a187-86446ffb36be', tool_call_id='8597d68e-eee3-4954-900b-471354a56953'), AIMessage(content='The capital of India is New Delhi.', additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'safety_ratings': []}, id='run--d820dbad-c450-4a07-9eda-372b6547d871-0', usage_metadata={'input_tokens': 443, 'output_tokens': 9, 'total_tokens': 452, 'input_token_details': {'cache_read': 0}}), HumanMessage(content='what is 2+2?', additional_kwargs={}, response_metadata={}, id='59b99c6b-93ba-4cf4-b54f-26c357080471')]}, next=('chatbot',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f ...
#  StateSnapshot(values={'messages': [HumanMessage(content='hi', additional_kwargs={}, response_metadata={}, id='33234813-63d0-4c23-b948-aa5e58e2c942'), AIMessage(content='Hello! How can I help you today?', additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'safety_ratings': []}, id='run--ebcd353c-50ec-480f-b20e-6e1359b53cbd-0', usage_metadata={'input_tokens': 72, 'output_tokens': 10, 'total_tokens': 82, 'input_token_details': {'cache_read': 0}}), HumanMessage(content='my name is priya', additional_kwargs={}, response_metadata={}, id='6bf90083-47a5-4212-ac91-d1c03f528de5'), AIMessage(content='Nice to meet you, Priya!  Is there anything I can assist you with?', additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'safety_ratings': []}, id='run--53c0e928-a543-47e6-9fce-dec1eac9e317-0', usage_metadata={'input_tokens': 86, 'output_tokens': 18, 'total_tokens': 104, 'input_token_details': {'cache_read': 0}}), HumanMessage(content="what is india's capital?", additional_kwargs={}, response_metadata={}, id='99c83094-3f9f-41ba-93dd-614cbe622c2d'), AIMessage(content='', additional_kwargs={'function_call': {'name': 'search', 'arguments': '{"__arg1": "India capital"}'}}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'safety_ratings': []}, id='run--aac4493f-56e5-4b46-9c3d-75eb56d5a815-0', tool_calls=[{'name': 'search', 'args': {'__arg1': 'India capital'}, 'id': '8597d68e-eee3-4954-900b-471354a56953', 'type': 'tool_call'}], usage_metadata={'input_tokens': 110, 'output_tokens': 6, 'total_tokens': 116, 'input_token_details': {'cache_read': 0}}), ToolMessage(content="New Delhi is the capital of India and a part of the National Capital Territory of Delhi (NCT). New Delhi is the seat of all three branches of the Government ... Delhi, officially the National Capital Territory (NCT) of Delhi, is a city and a union territory of India containing New Delhi, the capital of India. New Delhi, national capital of India. It is situated in the north-central part of the country on the west bank of the Yamuna River. India Capital has invested exclusively in Indian public equities since 1994. We focus intensively on fundamental research to identify long-term investments ... Thus, in 1911, New Delhi became the capital of India, south of the Old City of Delhi. And then over the years, Delhi expanded, and satellite ... From its origins as 'Indraprastha' in the Mahabharata to becoming the capital in 1911, Delhi blends ancient charm and modern governance. Its appealing old monuments, busy street bazaars and chaotic traffic roads make Delhi one of the most intense destinations that you can visit. There are 28 states and 8 Union territories in the country. Union Territories are administered by the President through an Administrator appointed by him/her. What is the Capital of India? Capital City, New Delhi. Capital location, 28 36 N, 77 12 E. Capital - history, the city's name is associated with various myths ... Lying in the northern part of the country, Delhi is surrounded by Haryana on all sides except the east, where it borders with Uttar Pradesh.", name='search', id='0e690daf-bf1f-4101-a187-86446ffb36be', tool_call_id='8597d68e-eee3-4954-900b-471354a56953'), AIMessage(content='The capital of India is New Delhi.', additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'safety_ratings': []}, id='run--d820dbad-c450-4a07-9eda-372b6547d871-0', usage_metadata={'input_tokens': 443, 'output_tokens': 9, 'total_tokens': 452, 'input_token_details': {'cache_read': 0}})]}, next=('__start__',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0919de-4598-6b38-800a-57a4b697b57f'}}, metadata={'source': 'input', 'writes': {'__start__': {'messages': [{'role': 'user',  ...
#  StateSnapshot(values={'messages': [HumanMessage(content='hi', additional_kwargs={}, response_metadata={}, id='33234813-63d0-4c23-b948-aa5e58e2c942'), AIMessage(content='Hello! How can I help you today?', additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'safety_ratings': []}, id='run--ebcd353c-50ec-480f-b20e-6e1359b53cbd-0', usage_metadata={'input_tokens': 72, 'output_tokens': 10, 'total_tokens': 82, 'input_token_details': {'cache_read': 0}}), HumanMessage(content='my name is priya', additional_kwargs={}, response_metadata={}, id='6bf90083-47a5-4212-ac91-d1c03f528de5'), AIMessage(content='Nice to meet you, Priya!  Is there anything I can assist you with?', additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'safety_ratings': []}, id='run--53c0e928-a543-47e6-9fce-dec1eac9e317-0', usage_metadata={'input_tokens': 86, 'output_tokens': 18, 'total_tokens': 104, 'input_token_details': {'cache_read': 0}}), HumanMessage(content="what is india's capital?", additional_kwargs={}, response_metadata={}, id='99c83094-3f9f-41ba-93dd-614cbe622c2d'), AIMessage(content='', additional_kwargs={'function_call': {'name': 'search', 'arguments': '{"__arg1": "India capital"}'}}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'safety_ratings': []}, id='run--aac4493f-56e5-4b46-9c3d-75eb56d5a815-0', tool_calls=[{'name': 'search', 'args': {'__arg1': 'India capital'}, 'id': '8597d68e-eee3-4954-900b-471354a56953', 'type': 'tool_call'}], usage_metadata={'input_tokens': 110, 'output_tokens': 6, 'total_tokens': 116, 'input_token_details': {'cache_read': 0}}), ToolMessage(content="New Delhi is the capital of India and a part of the National Capital Territory of Delhi (NCT). New Delhi is the seat of all three branches of the Government ... Delhi, officially the National Capital Territory (NCT) of Delhi, is a city and a union territory of India containing New Delhi, the capital of India. New Delhi, national capital of India. It is situated in the north-central part of the country on the west bank of the Yamuna River. India Capital has invested exclusively in Indian public equities since 1994. We focus intensively on fundamental research to identify long-term investments ... Thus, in 1911, New Delhi became the capital of India, south of the Old City of Delhi. And then over the years, Delhi expanded, and satellite ... From its origins as 'Indraprastha' in the Mahabharata to becoming the capital in 1911, Delhi blends ancient charm and modern governance. Its appealing old monuments, busy street bazaars and chaotic traffic roads make Delhi one of the most intense destinations that you can visit. There are 28 states and 8 Union territories in the country. Union Territories are administered by the President through an Administrator appointed by him/her. What is the Capital of India? Capital City, New Delhi. Capital location, 28 36 N, 77 12 E. Capital - history, the city's name is associated with various myths ... Lying in the northern part of the country, Delhi is surrounded by Haryana on all sides except the east, where it borders with Uttar Pradesh.", name='search', id='0e690daf-bf1f-4101-a187-86446ffb36be', tool_call_id='8597d68e-eee3-4954-900b-471354a56953'), AIMessage(content='The capital of India is New Delhi.', additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'safety_ratings': []}, id='run--d820dbad-c450-4a07-9eda-372b6547d871-0', usage_metadata={'input_tokens': 443, 'output_tokens': 9, 'total_tokens': 452, 'input_token_details': {'cache_read': 0}})]}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0919de-0781-66f6-8009-c9896a633e63'}}, metadata={'source': 'loop', 'writes': {'chatbot': {'messages': [AIMessage(content='The capital o ...
#  StateSnapshot(values={'messages': [HumanMessage(content='hi', additional_kwargs={}, response_metadata={}, id='33234813-63d0-4c23-b948-aa5e58e2c942'), AIMessage(content='Hello! How can I help you today?', additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'safety_ratings': []}, id='run--ebcd353c-50ec-480f-b20e-6e1359b53cbd-0', usage_metadata={'input_tokens': 72, 'output_tokens': 10, 'total_tokens': 82, 'input_token_details': {'cache_read': 0}}), HumanMessage(content='my name is priya', additional_kwargs={}, response_metadata={}, id='6bf90083-47a5-4212-ac91-d1c03f528de5'), AIMessage(content='Nice to meet you, Priya!  Is there anything I can assist you with?', additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'safety_ratings': []}, id='run--53c0e928-a543-47e6-9fce-dec1eac9e317-0', usage_metadata={'input_tokens': 86, 'output_tokens': 18, 'total_tokens': 104, 'input_token_details': {'cache_read': 0}}), HumanMessage(content="what is india's capital?", additional_kwargs={}, response_metadata={}, id='99c83094-3f9f-41ba-93dd-614cbe622c2d'), AIMessage(content='', additional_kwargs={'function_call': {'name': 'search', 'arguments': '{"__arg1": "India capital"}'}}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'safety_ratings': []}, id='run--aac4493f-56e5-4b46-9c3d-75eb56d5a815-0', tool_calls=[{'name': 'search', 'args': {'__arg1': 'India capital'}, 'id': '8597d68e-eee3-4954-900b-471354a56953', 'type': 'tool_call'}], usage_metadata={'input_tokens': 110, 'output_tokens': 6, 'total_tokens': 116, 'input_token_details': {'cache_read': 0}}), ToolMessage(content="New Delhi is the capital of India and a part of the National Capital Territory of Delhi (NCT). New Delhi is the seat of all three branches of the Government ... Delhi, officially the National Capital Territory (NCT) of Delhi, is a city and a union territory of India containing New Delhi, the capital of India. New Delhi, national capital of India. It is situated in the north-central part of the country on the west bank of the Yamuna River. India Capital has invested exclusively in Indian public equities since 1994. We focus intensively on fundamental research to identify long-term investments ... Thus, in 1911, New Delhi became the capital of India, south of the Old City of Delhi. And then over the years, Delhi expanded, and satellite ... From its origins as 'Indraprastha' in the Mahabharata to becoming the capital in 1911, Delhi blends ancient charm and modern governance. Its appealing old monuments, busy street bazaars and chaotic traffic roads make Delhi one of the most intense destinations that you can visit. There are 28 states and 8 Union territories in the country. Union Territories are administered by the President through an Administrator appointed by him/her. What is the Capital of India? Capital City, New Delhi. Capital location, 28 36 N, 77 12 E. Capital - history, the city's name is associated with various myths ... Lying in the northern part of the country, Delhi is surrounded by Haryana on all sides except the east, where it borders with Uttar Pradesh.", name='search', id='0e690daf-bf1f-4101-a187-86446ffb36be', tool_call_id='8597d68e-eee3-4954-900b-471354a56953')]}, next=('chatbot',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0919dd-fef6-666c-8008-54f2fece1af1'}}, metadata={'source': 'loop', 'writes': {'tools': {'messages': [ToolMessage(content="New Delhi is the capital of India and a part of the National Capital Territory of Delhi (NCT). New Delhi is the seat of all three branches of the Government ... Delhi, officially the National Capital Territory (NCT) of Delhi, is a city and a union territory of India containing New Delhi, the capital of India. New Delhi, national capital of India. It is situated in the north-centr ...
#  StateSnapshot(values={'messages': [HumanMessage(content='hi', additional_kwargs={}, response_metadata={}, id='33234813-63d0-4c23-b948-aa5e58e2c942'), AIMessage(content='Hello! How can I help you today?', additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'safety_ratings': []}, id='run--ebcd353c-50ec-480f-b20e-6e1359b53cbd-0', usage_metadata={'input_tokens': 72, 'output_tokens': 10, 'total_tokens': 82, 'input_token_details': {'cache_read': 0}}), HumanMessage(content='my name is priya', additional_kwargs={}, response_metadata={}, id='6bf90083-47a5-4212-ac91-d1c03f528de5'), AIMessage(content='Nice to meet you, Priya!  Is there anything I can assist you with?', additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'safety_ratings': []}, id='run--53c0e928-a543-47e6-9fce-dec1eac9e317-0', usage_metadata={'input_tokens': 86, 'output_tokens': 18, 'total_tokens': 104, 'input_token_details': {'cache_read': 0}}), HumanMessage(content="what is india's capital?", additional_kwargs={}, response_metadata={}, id='99c83094-3f9f-41ba-93dd-614cbe622c2d'), AIMessage(content='', additional_kwargs={'function_call': {'name': 'search', 'arguments': '{"__arg1": "India capital"}'}}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'safety_ratings': []}, id='run--aac4493f-56e5-4b46-9c3d-75eb56d5a815-0', tool_calls=[{'name': 'search', 'args': {'__arg1': 'India capital'}, 'id': '8597d68e-eee3-4954-900b-471354a56953', 'type': 'tool_call'}], usage_metadata={'input_tokens': 110, 'output_tokens': 6, 'total_tokens': 116, 'input_token_details': {'cache_read': 0}})]}, next=('tools',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0919dd-d8da-6172-8007-ba25debcace1'}}, metadata={'source': 'loop', 'writes': {'chatbot': {'messages': [AIMessage(content='', additional_kwargs={'function_call': {'name': 'search', 'arguments': '{"__arg1": "India capital"}'}}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'safety_ratings': []}, id='run--aac4493f-56e5-4b46-9c3d-75eb56d5a815-0', tool_calls=[{'name': 'search', 'args': {'__arg1': 'India capital'}, 'id': '8597d68e-eee3-4954-900b-471354a56953', 'type': 'tool_call'}], usage_metadata={'input_tokens': 110, 'output_tokens': 6, 'total_tokens': 116, 'input_token_details': {'cache_read': 0}})]}}, 'step': 7, 'parents': {}, 'thread_id': '1'}, created_at='2025-09-14T19:06:06.142482+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0919dd-d13d-6874-8006-dfe727fa5984'}}, tasks=(PregelTask(id='d842b41c-1078-94e6-dfca-ca306a6f3f45', name='tools', path=('__pregel_pull', 'tools'), error=None, interrupts=(), state=None, result={'messages': [ToolMessage(content="New Delhi is the capital of India and a part of the National Capital Territory of Delhi (NCT). New Delhi is the seat of all three branches of the Government ... Delhi, officially the National Capital Territory (NCT) of Delhi, is a city and a union territory of India containing New Delhi, the capital of India. New Delhi, national capital of India. It is situated in the north-central part of the country on the west bank of the Yamuna River. India Capital has invested exclusively in Indian public equities since 1994. We focus intensively on fundamental research to identify long-term investments ... Thus, in 1911, New Delhi became the capital of India, south of the Old City of Delhi. And then over the years, Delhi expanded, and satellite ... From its origins as 'Indraprastha' in the Mahabharata to becoming the capital in 1911, Delhi blends ancient charm and modern governance. Its appealing old monuments, busy street bazaars and chaotic traffic roads make Delhi one of the most intense destinations that you can visit. There are 28 states and 8  ...
#  StateSnapshot(values={'messages': [HumanMessage(content='hi', additional_kwargs={}, response_metadata={}, id='33234813-63d0-4c23-b948-aa5e58e2c942'), AIMessage(content='Hello! How can I help you today?', additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'safety_ratings': []}, id='run--ebcd353c-50ec-480f-b20e-6e1359b53cbd-0', usage_metadata={'input_tokens': 72, 'output_tokens': 10, 'total_tokens': 82, 'input_token_details': {'cache_read': 0}}), HumanMessage(content='my name is priya', additional_kwargs={}, response_metadata={}, id='6bf90083-47a5-4212-ac91-d1c03f528de5'), AIMessage(content='Nice to meet you, Priya!  Is there anything I can assist you with?', additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'safety_ratings': []}, id='run--53c0e928-a543-47e6-9fce-dec1eac9e317-0', usage_metadata={'input_tokens': 86, 'output_tokens': 18, 'total_tokens': 104, 'input_token_details': {'cache_read': 0}}), HumanMessage(content="what is india's capital?", additional_kwargs={}, response_metadata={}, id='99c83094-3f9f-41ba-93dd-614cbe622c2d')]}, next=('chatbot',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0919dd-d13d-6874-8006-dfe727fa5984'}}, metadata={'source': 'loop', 'writes': None, 'step': 6, 'parents': {}, 'thread_id': '1'}, created_at='2025-09-14T19:06:05.344365+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0919dd-d13c-6b2c-8005-68fcdc9d5b3b'}}, tasks=(PregelTask(id='3aae2829-77a5-c8a8-5be6-8c220d24ae8a', name='chatbot', path=('__pregel_pull', 'chatbot'), error=None, interrupts=(), state=None, result={'messages': [AIMessage(content='', additional_kwargs={'function_call': {'name': 'search', 'arguments': '{"__arg1": "India capital"}'}}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'safety_ratings': []}, id='run--aac4493f-56e5-4b46-9c3d-75eb56d5a815-0', tool_calls=[{'name': 'search', 'args': {'__arg1': 'India capital'}, 'id': '8597d68e-eee3-4954-900b-471354a56953', 'type': 'tool_call'}], usage_metadata={'input_tokens': 110, 'output_tokens': 6, 'total_tokens': 116, 'input_token_details': {'cache_read': 0}})]}),), interrupts=()),
#  StateSnapshot(values={'messages': [HumanMessage(content='hi', additional_kwargs={}, response_metadata={}, id='33234813-63d0-4c23-b948-aa5e58e2c942'), AIMessage(content='Hello! How can I help you today?', additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'safety_ratings': []}, id='run--ebcd353c-50ec-480f-b20e-6e1359b53cbd-0', usage_metadata={'input_tokens': 72, 'output_tokens': 10, 'total_tokens': 82, 'input_token_details': {'cache_read': 0}}), HumanMessage(content='my name is priya', additional_kwargs={}, response_metadata={}, id='6bf90083-47a5-4212-ac91-d1c03f528de5'), AIMessage(content='Nice to meet you, Priya!  Is there anything I can assist you with?', additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'safety_ratings': []}, id='run--53c0e928-a543-47e6-9fce-dec1eac9e317-0', usage_metadata={'input_tokens': 86, 'output_tokens': 18, 'total_tokens': 104, 'input_token_details': {'cache_read': 0}})]}, next=('__start__',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0919dd-d13c-6b2c-8005-68fcdc9d5b3b'}}, metadata={'source': 'input', 'writes': {'__start__': {'messages': [{'role': 'user', 'content': "what is india's capital?"}]}}, 'step': 5, 'parents': {}, 'thread_id': '1'}, created_at='2025-09-14T19:06:05.344024+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0919dd-80be-6cf4-8004-3f0af45fd8e9'}}, tasks=(PregelTask(id='64a868bd-bb56-edc9-b34a-b483eed84bec', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None, result={'messages': [{'role': 'user', 'content': "what is india's capital?"}]}),), interrupts=()),
#  StateSnapshot(values={'messages': [HumanMessage(content='hi', additional_kwargs={}, response_metadata={}, id='33234813-63d0-4c23-b948-aa5e58e2c942'), AIMessage(content='Hello! How can I help you today?', additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'safety_ratings': []}, id='run--ebcd353c-50ec-480f-b20e-6e1359b53cbd-0', usage_metadata={'input_tokens': 72, 'output_tokens': 10, 'total_tokens': 82, 'input_token_details': {'cache_read': 0}}), HumanMessage(content='my name is priya', additional_kwargs={}, response_metadata={}, id='6bf90083-47a5-4212-ac91-d1c03f528de5'), AIMessage(content='Nice to meet you, Priya!  Is there anything I can assist you with?', additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'safety_ratings': []}, id='run--53c0e928-a543-47e6-9fce-dec1eac9e317-0', usage_metadata={'input_tokens': 86, 'output_tokens': 18, 'total_tokens': 104, 'input_token_details': {'cache_read': 0}})]}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0919dd-80be-6cf4-8004-3f0af45fd8e9'}}, metadata={'source': 'loop', 'writes': {'chatbot': {'messages': [AIMessage(content='Nice to meet you, Priya!  Is there anything I can assist you with?', additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'safety_ratings': []}, id='run--53c0e928-a543-47e6-9fce-dec1eac9e317-0', usage_metadata={'input_tokens': 86, 'output_tokens': 18, 'total_tokens': 104, 'input_token_details': {'cache_read': 0}})]}}, 'step': 4, 'parents': {}, 'thread_id': '1'}, created_at='2025-09-14T19:05:56.903842+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0919dd-7a82-6d0e-8003-f1f3dcdd725a'}}, tasks=(), interrupts=()),
#  StateSnapshot(values={'messages': [HumanMessage(content='hi', additional_kwargs={}, response_metadata={}, id='33234813-63d0-4c23-b948-aa5e58e2c942'), AIMessage(content='Hello! How can I help you today?', additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'safety_ratings': []}, id='run--ebcd353c-50ec-480f-b20e-6e1359b53cbd-0', usage_metadata={'input_tokens': 72, 'output_tokens': 10, 'total_tokens': 82, 'input_token_details': {'cache_read': 0}}), HumanMessage(content='my name is priya', additional_kwargs={}, response_metadata={}, id='6bf90083-47a5-4212-ac91-d1c03f528de5')]}, next=('chatbot',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0919dd-7a82-6d0e-8003-f1f3dcdd725a'}}, metadata={'source': 'loop', 'writes': None, 'step': 3, 'parents': {}, 'thread_id': '1'}, created_at='2025-09-14T19:05:56.250131+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0919dd-7a81-676a-8002-8eab2da3c6c2'}}, tasks=(PregelTask(id='0d9e3346-df7b-2ce4-4129-a7059a577ac8', name='chatbot', path=('__pregel_pull', 'chatbot'), error=None, interrupts=(), state=None, result={'messages': [AIMessage(content='Nice to meet you, Priya!  Is there anything I can assist you with?', additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'safety_ratings': []}, id='run--53c0e928-a543-47e6-9fce-dec1eac9e317-0', usage_metadata={'input_tokens': 86, 'output_tokens': 18, 'total_tokens': 104, 'input_token_details': {'cache_read': 0}})]}),), interrupts=()),
#  StateSnapshot(values={'messages': [HumanMessage(content='hi', additional_kwargs={}, response_metadata={}, id='33234813-63d0-4c23-b948-aa5e58e2c942'), AIMessage(content='Hello! How can I help you today?', additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'safety_ratings': []}, id='run--ebcd353c-50ec-480f-b20e-6e1359b53cbd-0', usage_metadata={'input_tokens': 72, 'output_tokens': 10, 'total_tokens': 82, 'input_token_details': {'cache_read': 0}})]}, next=('__start__',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0919dd-7a81-676a-8002-8eab2da3c6c2'}}, metadata={'source': 'input', 'writes': {'__start__': {'messages': [{'role': 'user', 'content': 'my name is priya'}]}}, 'step': 2, 'parents': {}, 'thread_id': '1'}, created_at='2025-09-14T19:05:56.249572+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0919dd-3a51-621c-8001-47a8f19d4e8e'}}, tasks=(PregelTask(id='effecc26-ffc0-dadf-4a09-9977296d6c83', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None, result={'messages': [{'role': 'user', 'content': 'my name is priya'}]}),), interrupts=()),
#  StateSnapshot(values={'messages': [HumanMessage(content='hi', additional_kwargs={}, response_metadata={}, id='33234813-63d0-4c23-b948-aa5e58e2c942'), AIMessage(content='Hello! How can I help you today?', additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'safety_ratings': []}, id='run--ebcd353c-50ec-480f-b20e-6e1359b53cbd-0', usage_metadata={'input_tokens': 72, 'output_tokens': 10, 'total_tokens': 82, 'input_token_details': {'cache_read': 0}})]}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0919dd-3a51-621c-8001-47a8f19d4e8e'}}, metadata={'source': 'loop', 'writes': {'chatbot': {'messages': [AIMessage(content='Hello! How can I help you today?', additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'safety_ratings': []}, id='run--ebcd353c-50ec-480f-b20e-6e1359b53cbd-0', usage_metadata={'input_tokens': 72, 'output_tokens': 10, 'total_tokens': 82, 'input_token_details': {'cache_read': 0}})]}}, 'step': 1, 'parents': {}, 'thread_id': '1'}, created_at='2025-09-14T19:05:49.518884+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0919dd-2820-6b60-8000-0ec545bb3c0c'}}, tasks=(), interrupts=()),
#  StateSnapshot(values={'messages': [HumanMessage(content='hi', additional_kwargs={}, response_metadata={}, id='33234813-63d0-4c23-b948-aa5e58e2c942')]}, next=('chatbot',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0919dd-2820-6b60-8000-0ec545bb3c0c'}}, metadata={'source': 'loop', 'writes': None, 'step': 0, 'parents': {}, 'thread_id': '1'}, created_at='2025-09-14T19:05:47.611625+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0919dd-281d-6190-bfff-2da815d12e1b'}}, tasks=(PregelTask(id='b455d4fc-5530-3bce-436a-88d89180b392', name='chatbot', path=('__pregel_pull', 'chatbot'), error=None, interrupts=(), state=None, result={'messages': [AIMessage(content='Hello! How can I help you today?', additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'safety_ratings': []}, id='run--ebcd353c-50ec-480f-b20e-6e1359b53cbd-0', usage_metadata={'input_tokens': 72, 'output_tokens': 10, 'total_tokens': 82, 'input_token_details': {'cache_read': 0}})]}),), interrupts=()),
#  StateSnapshot(values={'messages': []}, next=('__start__',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0919dd-281d-6190-bfff-2da815d12e1b'}}, metadata={'source': 'input', 'writes': {'__start__': {'messages': [{'role': 'user', 'content': 'hi'}]}}, 'step': -1, 'parents': {}, 'thread_id': '1'}, created_at='2025-09-14T19:05:47.610147+00:00', parent_config=None, tasks=(PregelTask(id='77b518f4-a6e1-7d0e-55fe-d92be42e55c5', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None, result={'messages': [{'role': 'user', 'content': 'hi'}]}),), interrupts=())]

# %% [markdown]
# ### LangGraph gives you tools to set the state back to a prior point in time, to branch off:
#
# ```
# config = {"configurable": {"thread_id": "1", "checkpoint_id": ...}}
# graph.invoke(None, config=config)
# ```
#
# And this allows you to build stable systems that can be recovered and rerun from any prior checkpoint.

# %% [markdown]
# ### And now let's store in SQL
#
# ### And this is the power of LangGraph.

# %%
import sqlite3
from langgraph.checkpoint.sqlite import SqliteSaver

db_path = "memory.db"
conn = sqlite3.connect(db_path, check_same_thread=False)
sql_memory = SqliteSaver(conn)

# %%
# Steps 1 and 2
graph_builder = StateGraph(State)


# Step 3
llm = ChatGoogleGenerativeAI(
    model="gemini-1.5-flash",   
    api_key=os.getenv("GEMINI_API_KEY")
)
llm_with_tools = llm.bind_tools(tools)

def chatbot(state: State):
    print(state)
    return {"messages": [llm_with_tools.invoke(state["messages"])]}

graph_builder.add_node("chatbot", chatbot)
graph_builder.add_node("tools", ToolNode(tools=tools))

# Step 4
graph_builder.add_conditional_edges( "chatbot", tools_condition, "tools")
graph_builder.add_edge("tools", "chatbot")
graph_builder.add_edge(START, "chatbot")

# Step 5
graph = graph_builder.compile(checkpointer=sql_memory)
display(Image(graph.get_graph().draw_mermaid_png()))

# %%
config = {"configurable": {"thread_id": "2"}}

def chat(user_input: str, history):
    result = graph.invoke({"messages": [{"role": "user", "content": user_input}]}, config=config)
    return result["messages"][-1].content


gr.ChatInterface(chat, type="messages").launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7869
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7869/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# {'messages': [HumanMessage(content='hi there', additional_kwargs={}, response_metadata={}, id='34b75745-7e98-4ea9-aca0-46bbf4a940cd'), AIMessage(content='Hello! How can I assist you today?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 11, 'prompt_tokens': 90, 'total_tokens': 101, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_b376dfbbd5', 'id': 'chatcmpl-BIlWUHrxBirJa2bgCDoKD1ay7IPJ0', 'finish_reason': 'stop', 'logprobs': None}, id='run-128cd208-7bbd-4401-b5ac-bede1b5f2309-0', usage_metadata={'input_tokens': 90, 'output_tokens': 11, 'total_tokens': 101, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), HumanMessage(content="my name's ed", additional_kwargs={}, response_metadata={}, id='1d77d57c-b3fb-4ad4-9e2f-abec90aed153'), AIMessage(content='Nice to meet you, Ed! How can I help you today?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 16, 'prompt_tokens': 111, 'total_tokens': 127, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_b376dfbbd5', 'id': 'chatcmpl-BIlWfnfuifEen42zQkrYp59KIYcab', 'finish_reason': 'stop', 'logprobs': None}, id='run-86bb1069-e30e-4867-9d78-75eb4f3af685-0', usage_metadata={'input_tokens': 111, 'output_tokens': 16, 'total_tokens': 127, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), HumanMessage(content="what's my name?", additional_kwargs={}, response_metadata={}, id='f963980c-5cc3-462e-9d89-6322b941b74f'), AIMessage(content='Your name is Ed. How can I assist you further?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 14, 'prompt_tokens': 138, 'total_tokens': 152, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_b376dfbbd5', 'id': 'chatcmpl-BIlWkhLUoMrkbXKIgWvjU0VdTnkA2', 'finish_reason': 'stop', 'logprobs': None}, id='run-8bf9f8a1-01d8-4383-bd36-865106d10b4e-0', usage_metadata={'input_tokens': 138, 'output_tokens': 14, 'total_tokens': 152, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), HumanMessage(content='hi there', additional_kwargs={}, response_metadata={}, id='d6b7078c-b230-47d1-a06c-ee4bff8dc520'), AIMessage(content='Hello again, Ed! What would you like to talk about?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 15, 'prompt_tokens': 160, 'total_tokens': 175, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_b376dfbbd5', 'id': 'chatcmpl-BIlaoadAVuMS7myiJYgjBJ5abTtEf', 'finish_reason': 'stop', 'logprobs': None}, id='run-54035c4c-2a9b-4a57-b720-0c19a3557d93-0', usage_metadata={'input_tokens': 160, 'output_tokens': 15, 'total_tokens': 175, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), HumanMessage(content='what is my name?', additional_kwargs={}, response_metadata={}, id='55009a7a-1713-4f89-a405-f72a870e7bf8'), AIMessage(content='Your name is Ed.', additional_kwargs={}, response_metadata= ...
# {'messages': [HumanMessage(content='hi there', additional_kwargs={}, response_metadata={}, id='34b75745-7e98-4ea9-aca0-46bbf4a940cd'), AIMessage(content='Hello! How can I assist you today?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 11, 'prompt_tokens': 90, 'total_tokens': 101, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_b376dfbbd5', 'id': 'chatcmpl-BIlWUHrxBirJa2bgCDoKD1ay7IPJ0', 'finish_reason': 'stop', 'logprobs': None}, id='run-128cd208-7bbd-4401-b5ac-bede1b5f2309-0', usage_metadata={'input_tokens': 90, 'output_tokens': 11, 'total_tokens': 101, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), HumanMessage(content="my name's ed", additional_kwargs={}, response_metadata={}, id='1d77d57c-b3fb-4ad4-9e2f-abec90aed153'), AIMessage(content='Nice to meet you, Ed! How can I help you today?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 16, 'prompt_tokens': 111, 'total_tokens': 127, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_b376dfbbd5', 'id': 'chatcmpl-BIlWfnfuifEen42zQkrYp59KIYcab', 'finish_reason': 'stop', 'logprobs': None}, id='run-86bb1069-e30e-4867-9d78-75eb4f3af685-0', usage_metadata={'input_tokens': 111, 'output_tokens': 16, 'total_tokens': 127, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), HumanMessage(content="what's my name?", additional_kwargs={}, response_metadata={}, id='f963980c-5cc3-462e-9d89-6322b941b74f'), AIMessage(content='Your name is Ed. How can I assist you further?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 14, 'prompt_tokens': 138, 'total_tokens': 152, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_b376dfbbd5', 'id': 'chatcmpl-BIlWkhLUoMrkbXKIgWvjU0VdTnkA2', 'finish_reason': 'stop', 'logprobs': None}, id='run-8bf9f8a1-01d8-4383-bd36-865106d10b4e-0', usage_metadata={'input_tokens': 138, 'output_tokens': 14, 'total_tokens': 152, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), HumanMessage(content='hi there', additional_kwargs={}, response_metadata={}, id='d6b7078c-b230-47d1-a06c-ee4bff8dc520'), AIMessage(content='Hello again, Ed! What would you like to talk about?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 15, 'prompt_tokens': 160, 'total_tokens': 175, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_b376dfbbd5', 'id': 'chatcmpl-BIlaoadAVuMS7myiJYgjBJ5abTtEf', 'finish_reason': 'stop', 'logprobs': None}, id='run-54035c4c-2a9b-4a57-b720-0c19a3557d93-0', usage_metadata={'input_tokens': 160, 'output_tokens': 15, 'total_tokens': 175, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), HumanMessage(content='what is my name?', additional_kwargs={}, response_metadata={}, id='55009a7a-1713-4f89-a405-f72a870e7bf8'), AIMessage(content='Your name is Ed.', additional_kwargs={}, response_metadata= ...
# {'messages': [HumanMessage(content='hi there', additional_kwargs={}, response_metadata={}, id='34b75745-7e98-4ea9-aca0-46bbf4a940cd'), AIMessage(content='Hello! How can I assist you today?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 11, 'prompt_tokens': 90, 'total_tokens': 101, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_b376dfbbd5', 'id': 'chatcmpl-BIlWUHrxBirJa2bgCDoKD1ay7IPJ0', 'finish_reason': 'stop', 'logprobs': None}, id='run-128cd208-7bbd-4401-b5ac-bede1b5f2309-0', usage_metadata={'input_tokens': 90, 'output_tokens': 11, 'total_tokens': 101, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), HumanMessage(content="my name's ed", additional_kwargs={}, response_metadata={}, id='1d77d57c-b3fb-4ad4-9e2f-abec90aed153'), AIMessage(content='Nice to meet you, Ed! How can I help you today?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 16, 'prompt_tokens': 111, 'total_tokens': 127, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_b376dfbbd5', 'id': 'chatcmpl-BIlWfnfuifEen42zQkrYp59KIYcab', 'finish_reason': 'stop', 'logprobs': None}, id='run-86bb1069-e30e-4867-9d78-75eb4f3af685-0', usage_metadata={'input_tokens': 111, 'output_tokens': 16, 'total_tokens': 127, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), HumanMessage(content="what's my name?", additional_kwargs={}, response_metadata={}, id='f963980c-5cc3-462e-9d89-6322b941b74f'), AIMessage(content='Your name is Ed. How can I assist you further?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 14, 'prompt_tokens': 138, 'total_tokens': 152, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_b376dfbbd5', 'id': 'chatcmpl-BIlWkhLUoMrkbXKIgWvjU0VdTnkA2', 'finish_reason': 'stop', 'logprobs': None}, id='run-8bf9f8a1-01d8-4383-bd36-865106d10b4e-0', usage_metadata={'input_tokens': 138, 'output_tokens': 14, 'total_tokens': 152, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), HumanMessage(content='hi there', additional_kwargs={}, response_metadata={}, id='d6b7078c-b230-47d1-a06c-ee4bff8dc520'), AIMessage(content='Hello again, Ed! What would you like to talk about?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 15, 'prompt_tokens': 160, 'total_tokens': 175, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_b376dfbbd5', 'id': 'chatcmpl-BIlaoadAVuMS7myiJYgjBJ5abTtEf', 'finish_reason': 'stop', 'logprobs': None}, id='run-54035c4c-2a9b-4a57-b720-0c19a3557d93-0', usage_metadata={'input_tokens': 160, 'output_tokens': 15, 'total_tokens': 175, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), HumanMessage(content='what is my name?', additional_kwargs={}, response_metadata={}, id='55009a7a-1713-4f89-a405-f72a870e7bf8'), AIMessage(content='Your name is Ed.', additional_kwargs={}, response_metadata= ...
# {'messages': [HumanMessage(content='hi there', additional_kwargs={}, response_metadata={}, id='34b75745-7e98-4ea9-aca0-46bbf4a940cd'), AIMessage(content='Hello! How can I assist you today?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 11, 'prompt_tokens': 90, 'total_tokens': 101, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_b376dfbbd5', 'id': 'chatcmpl-BIlWUHrxBirJa2bgCDoKD1ay7IPJ0', 'finish_reason': 'stop', 'logprobs': None}, id='run-128cd208-7bbd-4401-b5ac-bede1b5f2309-0', usage_metadata={'input_tokens': 90, 'output_tokens': 11, 'total_tokens': 101, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), HumanMessage(content="my name's ed", additional_kwargs={}, response_metadata={}, id='1d77d57c-b3fb-4ad4-9e2f-abec90aed153'), AIMessage(content='Nice to meet you, Ed! How can I help you today?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 16, 'prompt_tokens': 111, 'total_tokens': 127, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_b376dfbbd5', 'id': 'chatcmpl-BIlWfnfuifEen42zQkrYp59KIYcab', 'finish_reason': 'stop', 'logprobs': None}, id='run-86bb1069-e30e-4867-9d78-75eb4f3af685-0', usage_metadata={'input_tokens': 111, 'output_tokens': 16, 'total_tokens': 127, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), HumanMessage(content="what's my name?", additional_kwargs={}, response_metadata={}, id='f963980c-5cc3-462e-9d89-6322b941b74f'), AIMessage(content='Your name is Ed. How can I assist you further?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 14, 'prompt_tokens': 138, 'total_tokens': 152, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_b376dfbbd5', 'id': 'chatcmpl-BIlWkhLUoMrkbXKIgWvjU0VdTnkA2', 'finish_reason': 'stop', 'logprobs': None}, id='run-8bf9f8a1-01d8-4383-bd36-865106d10b4e-0', usage_metadata={'input_tokens': 138, 'output_tokens': 14, 'total_tokens': 152, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), HumanMessage(content='hi there', additional_kwargs={}, response_metadata={}, id='d6b7078c-b230-47d1-a06c-ee4bff8dc520'), AIMessage(content='Hello again, Ed! What would you like to talk about?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 15, 'prompt_tokens': 160, 'total_tokens': 175, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_b376dfbbd5', 'id': 'chatcmpl-BIlaoadAVuMS7myiJYgjBJ5abTtEf', 'finish_reason': 'stop', 'logprobs': None}, id='run-54035c4c-2a9b-4a57-b720-0c19a3557d93-0', usage_metadata={'input_tokens': 160, 'output_tokens': 15, 'total_tokens': 175, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), HumanMessage(content='what is my name?', additional_kwargs={}, response_metadata={}, id='55009a7a-1713-4f89-a405-f72a870e7bf8'), AIMessage(content='Your name is Ed.', additional_kwargs={}, response_metadata= ...
# {'messages': [HumanMessage(content='hi there', additional_kwargs={}, response_metadata={}, id='34b75745-7e98-4ea9-aca0-46bbf4a940cd'), AIMessage(content='Hello! How can I assist you today?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 11, 'prompt_tokens': 90, 'total_tokens': 101, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_b376dfbbd5', 'id': 'chatcmpl-BIlWUHrxBirJa2bgCDoKD1ay7IPJ0', 'finish_reason': 'stop', 'logprobs': None}, id='run-128cd208-7bbd-4401-b5ac-bede1b5f2309-0', usage_metadata={'input_tokens': 90, 'output_tokens': 11, 'total_tokens': 101, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), HumanMessage(content="my name's ed", additional_kwargs={}, response_metadata={}, id='1d77d57c-b3fb-4ad4-9e2f-abec90aed153'), AIMessage(content='Nice to meet you, Ed! How can I help you today?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 16, 'prompt_tokens': 111, 'total_tokens': 127, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_b376dfbbd5', 'id': 'chatcmpl-BIlWfnfuifEen42zQkrYp59KIYcab', 'finish_reason': 'stop', 'logprobs': None}, id='run-86bb1069-e30e-4867-9d78-75eb4f3af685-0', usage_metadata={'input_tokens': 111, 'output_tokens': 16, 'total_tokens': 127, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), HumanMessage(content="what's my name?", additional_kwargs={}, response_metadata={}, id='f963980c-5cc3-462e-9d89-6322b941b74f'), AIMessage(content='Your name is Ed. How can I assist you further?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 14, 'prompt_tokens': 138, 'total_tokens': 152, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_b376dfbbd5', 'id': 'chatcmpl-BIlWkhLUoMrkbXKIgWvjU0VdTnkA2', 'finish_reason': 'stop', 'logprobs': None}, id='run-8bf9f8a1-01d8-4383-bd36-865106d10b4e-0', usage_metadata={'input_tokens': 138, 'output_tokens': 14, 'total_tokens': 152, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), HumanMessage(content='hi there', additional_kwargs={}, response_metadata={}, id='d6b7078c-b230-47d1-a06c-ee4bff8dc520'), AIMessage(content='Hello again, Ed! What would you like to talk about?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 15, 'prompt_tokens': 160, 'total_tokens': 175, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_b376dfbbd5', 'id': 'chatcmpl-BIlaoadAVuMS7myiJYgjBJ5abTtEf', 'finish_reason': 'stop', 'logprobs': None}, id='run-54035c4c-2a9b-4a57-b720-0c19a3557d93-0', usage_metadata={'input_tokens': 160, 'output_tokens': 15, 'total_tokens': 175, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), HumanMessage(content='what is my name?', additional_kwargs={}, response_metadata={}, id='55009a7a-1713-4f89-a405-f72a870e7bf8'), AIMessage(content='Your name is Ed.', additional_kwargs={}, response_metadata= ...
# {'messages': [HumanMessage(content='hi there', additional_kwargs={}, response_metadata={}, id='34b75745-7e98-4ea9-aca0-46bbf4a940cd'), AIMessage(content='Hello! How can I assist you today?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 11, 'prompt_tokens': 90, 'total_tokens': 101, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_b376dfbbd5', 'id': 'chatcmpl-BIlWUHrxBirJa2bgCDoKD1ay7IPJ0', 'finish_reason': 'stop', 'logprobs': None}, id='run-128cd208-7bbd-4401-b5ac-bede1b5f2309-0', usage_metadata={'input_tokens': 90, 'output_tokens': 11, 'total_tokens': 101, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), HumanMessage(content="my name's ed", additional_kwargs={}, response_metadata={}, id='1d77d57c-b3fb-4ad4-9e2f-abec90aed153'), AIMessage(content='Nice to meet you, Ed! How can I help you today?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 16, 'prompt_tokens': 111, 'total_tokens': 127, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_b376dfbbd5', 'id': 'chatcmpl-BIlWfnfuifEen42zQkrYp59KIYcab', 'finish_reason': 'stop', 'logprobs': None}, id='run-86bb1069-e30e-4867-9d78-75eb4f3af685-0', usage_metadata={'input_tokens': 111, 'output_tokens': 16, 'total_tokens': 127, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), HumanMessage(content="what's my name?", additional_kwargs={}, response_metadata={}, id='f963980c-5cc3-462e-9d89-6322b941b74f'), AIMessage(content='Your name is Ed. How can I assist you further?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 14, 'prompt_tokens': 138, 'total_tokens': 152, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_b376dfbbd5', 'id': 'chatcmpl-BIlWkhLUoMrkbXKIgWvjU0VdTnkA2', 'finish_reason': 'stop', 'logprobs': None}, id='run-8bf9f8a1-01d8-4383-bd36-865106d10b4e-0', usage_metadata={'input_tokens': 138, 'output_tokens': 14, 'total_tokens': 152, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), HumanMessage(content='hi there', additional_kwargs={}, response_metadata={}, id='d6b7078c-b230-47d1-a06c-ee4bff8dc520'), AIMessage(content='Hello again, Ed! What would you like to talk about?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 15, 'prompt_tokens': 160, 'total_tokens': 175, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_b376dfbbd5', 'id': 'chatcmpl-BIlaoadAVuMS7myiJYgjBJ5abTtEf', 'finish_reason': 'stop', 'logprobs': None}, id='run-54035c4c-2a9b-4a57-b720-0c19a3557d93-0', usage_metadata={'input_tokens': 160, 'output_tokens': 15, 'total_tokens': 175, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), HumanMessage(content='what is my name?', additional_kwargs={}, response_metadata={}, id='55009a7a-1713-4f89-a405-f72a870e7bf8'), AIMessage(content='Your name is Ed.', additional_kwargs={}, response_metadata= ...
